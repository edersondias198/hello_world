# %% [markdown]
# <a href="https://colab.research.google.com/github/edersondias198/hello_world/blob/main/atividade_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Estou aprendendo Python")
# Out:
# Estou aprendendo Python

# %%
meu_nome = "Ederson"
print(meu_nome)
# Out:
# Ederson

# %%
cidade = "Guarapuava"
print(cidade)
# Out:
# Guarapuava

# %%
idade = 33
print(idade)
# Out:
# 33

# %%
print("Bem-vindo ao curso de Python")
# Out:
# Bem-vindo ao curso de Python

# %%
curso = "Desenvolvimento de Sistemas"
print(curso)
# Out:
# Desenvolvimento de Sistemas

# %%
nome = "Ederson"
print("Olá, " + nome)
# Out:
# Olá, Ederson

# %%
profissao = "Programador Python"
print("Eu quero ser " + profissao)
# Out:
# Eu quero ser Programador Python

# %%
nome_pessoa = "Ederson"
idade_pessoa = 33
print(f"Meu nome é {nome_pessoa} e tenho {idade_pessoa} anos.")
# Out:
# Meu nome é Ederson e tenho 33 anos.

# %%
time = "Sao paulo"
print(f"Meu time do coração é {time}")
# Out:
# Meu time do coração é Sao paulo

# %%
altura = 1.73
print(f"Minha altura é {altura} metros.")
# Out:
# Minha altura é 1.73 metros.

# %%
import datetime
ano_atual = datetime.datetime.now().year
print(f"Estamos no ano de {ano_atual}")
# Out:
# Estamos no ano de 2026

# %%
linguagem = "Python"
print(f"Estou estudando {linguagem}")
# Out:
# Estou estudando Python

# %%
nota = 9.5
print(f"Minha nota foi {nota}")
# Out:
# Minha nota foi 9.5

# %%
produto = "Camisa"
preco = 85.90
print(f"O produto {produto} custa R$ {preco}")
# Out:
# O produto Camisa custa R$ 85.9

# %%
bairro = "Santa Cruz"
print(f"Eu moro no bairro {bairro}")
# Out:
# Eu moro no bairro Santa Cruz

# %%
escola = "Ana Vanda Bassara"
print(f"Eu estudo na escola {escola}")
# Out:
# Eu estudo na escola Ana Vanda Bassara

# %%
nome_completo = "Ederson Dias Oliveira"
cidade_mora = "Guarapuava"
estado_mora = "Pr"
print(f"{nome_completo} mora em {cidade_mora} - {estado_mora}")
# Out:
# Ederson Dias Oliveira mora em Guarapuava - Pr

# %%
animal = "cachorro"
print(f"Meu animal favorito é o {animal}")
# Out:
# Meu animal favorito é o cachorro

# %%
marca = "Toyota"
modelo = "Corolla. pelo menos e um sonho e vou alcançar"
print(f"Eu tenho um {marca} modelo {modelo}")
# Out:
# Eu tenho um Toyota modelo Corolla. pelo menos e um sonho e vou alcançar
